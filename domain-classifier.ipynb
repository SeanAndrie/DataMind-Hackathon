# %% [markdown]
# # Import Dependencies

# %%
import os
import cv2

import insightface
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt

from tqdm import tqdm
from insightface.app import FaceAnalysis
from insightface.model_zoo import model_zoo
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Create Reference Data

# %%
main_dir = "dataset"

train_dir = os.path.join(main_dir, "train")
train_labels_csv = os.path.join(train_dir, "labels.csv")

test_dir = os.path.join(main_dir, "test")
ref_dir = os.path.join(main_dir, "reference_faces")

# %%
train_labels_df = pd.read_csv(train_labels_csv)
train_labels_df.head()
# Out:
#         filename  emp_id
# 0  face_0568.jpg  emp016
# 1  face_0433.jpg  emp014
# 2  face_1751.jpg  emp004
# 3  face_0675.jpg  emp028
# 4  face_0112.jpg  emp001

# %%
app = FaceAnalysis(name="buffalo_l", providers=['CUDAExecutionProvider', 'CPUExecutionProvider'])
app.prepare(ctx_id=0, det_size=(320, 320), det_thresh=0.2)
# Out:
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /home/seang/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /home/seang/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /home/seang/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /home/seang/.insightface/models/buffalo_l/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /home/seang/.insightface/models/buffalo_l/w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (320, 320)

# %%
def robust_face_detection(img, app, attempts=3):
    """Tries multiple detection strategies"""
    if img is None:
        return None
        
    strategies = [
        lambda x: x,  # Original
        lambda x: cv2.convertScaleAbs(x, alpha=1.5, beta=40),  # Brighten
        lambda x: cv2.equalizeHist(cv2.cvtColor(x, cv2.COLOR_BGR2GRAY))[:,:,np.newaxis].repeat(3,2),  # Hist equal
        lambda x: cv2.GaussianBlur(x, (5,5), 0),  # De-noise
        lambda x: cv2.medianBlur(x, 3),  # Alternative de-noise
    ]
    
    for i in range(attempts):
        try:
            modified = strategies[i](img) if i < len(strategies) else img
            faces = app.get(modified)
            if len(faces) > 0:
                return faces
        except Exception as e:
            print(f"Detection attempt {i+1} failed: {str(e)}")
            continue
    return None

# %%
def create_reference_embeddings(ref_dir, ref_labels):
    gallery = {emp_id: [] for emp_id in ref_labels}

    for emp_id in tqdm(gallery.keys(), desc="Creating Embeddings"):
        emp_dir = os.path.join(ref_dir, emp_id)
        if not os.path.isdir(emp_dir):
            continue

        for file in tqdm(sorted(os.listdir(emp_dir)), desc=f"Embedding {emp_id}"):
            if file.lower().endswith('.mp4'):
                continue
            filepath = os.path.join(emp_dir, file)
            try:
                img = cv2.imread(filepath)
                if img is None:
                    continue
                faces = robust_face_detection(img, app)
                if faces:
                    embedding = faces[0].embedding / np.linalg.norm(faces[0].embedding)
                    gallery[emp_id].append(embedding)
                else:
                    print(f"Warning: {filepath} - {len(faces)} faces detected")
            except Exception as e:
                print(f"Error processing {filepath}: {str(e)}")
                continue
        if gallery[emp_id]:
            gallery[emp_id] = np.array(gallery[emp_id])
        else:
            print(f"Warning: No valid faces found for {emp_id}")
            del gallery[emp_id]
    return gallery

ref_embed = create_reference_embeddings(ref_dir, sorted(os.listdir(ref_dir)))
# Out:
# Creating Embeddings:   0%|          | 0/34 [00:00<?, ?it/s]/home/seang/miniconda3/envs/DataMind/lib/python3.10/site-packages/insightface/utils/transform.py:68: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   P = np.linalg.lstsq(X_homo, Y)[0].T # Affine matrix. 3 x 4
# Embedding emp001: 100%|██████████| 13/13 [00:03<00:00,  4.29it/s]
# Embedding emp002: 100%|██████████| 13/13 [00:02<00:00,  4.75it/s]t]
# Embedding emp003: 100%|██████████| 11/11 [00:02<00:00,  4.45it/s]t]
# Embedding emp004: 100%|██████████| 15/15 [00:03<00:00,  4.84it/s]t]
# Embedding emp005: 100%|██████████| 14/14 [00:03<00:00,  4.46it/s]t]
# Embedding emp006: 100%|██████████| 8/8 [00:01<00:00,  5.28it/s]/it]
# Embedding emp007: 100%|██████████| 14/14 [00:03<00:00,  4.53it/s]t]
# Embedding emp008: 100%|██████████| 15/15 [00:03<00:00,  4.26it/s]t]
# Embedding emp009: 100%|██████████| 17/17 [00:03<00:00,  4.39it/s]t]
# Embedding emp010: 100%|██████████| 15/15 [00:04<00:00,  3.75it/s]t]
# Embedding emp011: 100%|██████████| 11/11 [00:02<00:00,  4.16it/s]it]
# Embedding emp012: 100%|██████████| 14/14 [00:03<00:00,  4.12it/s]it]
# Embedding emp013: 100%|██████████| 16/16 [00:04<00:00,  3.80it/s]it]
# Embedding emp014: 100%|██████████| 15/15 [00:03<00:00,  4.62it/s]it]
# Embedding emp015: 100%|██████████| 15/15 [00:03<00:00,  4.68it/s]it]
# Embedding emp016: 100%|██████████| 15/15 [00:03<00:00,  4.38it/s]it]
# Embedding emp017: 100%|██████████| 14/14 [00:04<00:00,  3.35it/s]it]
# Embedding emp018: 100%|██████████| 20/20 [00:04<00:00,  4.32it/s]it]
# Embedding emp019: 100%|██████████| 15/15 [00:03<00:00,  3.98it/s]it]
# Embedding emp020: 100%|██████████| 15/15 [00:03<00:00,  4.01it/s]it]
# Embedding emp021: 100%|██████████| 15/15 [00:03<00:00,  3.98it/s]it]
# Embedding emp022: 100%|██████████| 15/15 [00:03<00:00,  4.52it/s]it]
# Embedding emp023: 100%|██████████| 15/15 [00:03<00:00,  4.56it/s]it]
# Embedding emp024: 100%|██████████| 11/11 [00:02<00:00,  4.58it/s]it]
# Embedding emp025: 100%|██████████| 14/14 [00:03<00:00,  4.23it/s]it]
# Embedding emp026: 100%|██████████| 17/17 [00:03<00:00,  4.36it/s]it]
# Embedding emp027: 100%|██████████| 15/15 [00:03<00:00,  4.14it/s]it]
# Embedding emp028: 100%|██████████| 15/15 [00:03<00:00,  3.91it/s]it]
# Embedding emp029: 100%|██████████| 13/13 [00:03<00:00,  4.05it/s]it]
# Embedding emp030: 100%|██████████| 15/15 [00:04<00:00,  3.47it/s]it]
# Embedding emp031: 100%|██████████| 15/15 [00:03<00:00,  4.07it/s]it]
# Embedding emp032: 100%|██████████| 15/15 [00:03<00:00,  3.80it/s]it]
# Embedding emp034: 100%|██████████| 11/11 [00:02<00:00,  4.37it/s]it]
# Embedding emp035: 100%|██████████| 15/15 [00:03<00:00,  4.38it/s]it]
# Creating Embeddings: 100%|██████████| 34/34 [01:55<00:00,  3.40s/it]

# %%
def create_train_embeddings(train_dir, labels_df, normalize=True):
    train_data = {"embedding": [], "label": []}
    missing = []
    img_path = os.path.join(train_dir, "images")
    for _, row in tqdm(labels_df.iterrows(), desc="Creating Train Embeddings", total=len(labels_df)):
        filename, emp_id = row
        filepath = os.path.join(img_path, filename)
        img = cv2.imread(filepath)
        faces = robust_face_detection(img, app)
        if faces:
            train_data['embedding'].append(faces[0].embedding)
            train_data['label'].append(emp_id)
        else:
            train_data['embedding'].append(np.random.normal(0, 0.01, 512))
            train_data['label'].append('UNKNOWN')
            missing.append((emp_id, filepath))
    return train_data, missing

train_dict, missing_train = create_train_embeddings(train_dir, train_labels_df)
# Out:
# Creating Train Embeddings: 100%|██████████| 1179/1179 [05:00<00:00,  3.92it/s]

# %%
((len(train_labels_df) - len(missing_train)) / len(train_labels_df)) * 100
# Out:
# 94.40203562340967

# %%
gallery_embed = np.vstack(list(ref_embed.values()))
gallery_labels = []

for id, embedding in ref_embed.items():
    for n in range(len(ref_embed[id])):
        gallery_labels.append(id)

len(gallery_embed), len(gallery_labels)
# Out:
# (452, 452)

# %%
all_classes = np.unique(list(ref_embed.keys()) + list(train_dict['label']))
le = LabelEncoder()
le.fit(all_classes)
# Out:
# LabelEncoder()

# %%
all_classes
# Out:
# array(['UNKNOWN', 'emp001', 'emp002', 'emp003', 'emp004', 'emp005',
#        'emp006', 'emp007', 'emp008', 'emp009', 'emp010', 'emp011',
#        'emp012', 'emp013', 'emp014', 'emp015', 'emp016', 'emp017',
#        'emp018', 'emp019', 'emp020', 'emp021', 'emp022', 'emp023',
#        'emp024', 'emp025', 'emp026', 'emp027', 'emp028', 'emp029',
#        'emp030', 'emp031', 'emp032', 'emp034', 'emp035'], dtype='<U7')

# %%
train_embed = np.array([x/np.linalg.norm(x) for x in train_dict['embedding']])  # Normalized
train_labels = le.transform(train_dict['label'])

X_train, X_valid, y_train, y_valid = train_test_split(
    train_embed, train_labels,
    test_size=0.2,
    random_state=42
)

gallery_embed = np.vstack([emb/np.linalg.norm(emb) for emb in ref_embed.values()])
gallery_labels = le.transform([id for id in ref_embed for _ in range(len(ref_embed[id]))])

# %%
X_train = np.vstack([X_train, gallery_embed])
y_train = np.hstack([y_train, gallery_labels])

# %%
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.svm import SVC

clf = xgb.XGBClassifier(
    objective="multi:softmax",
    eval_metric="mlogloss",  # Better for probabilities
    num_class=len(le.classes_),
    n_estimators=500,  # Reduced for faster training
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0.1,
    early_stopping_rounds=20
)

clf.fit(X_train, y_train, eval_set=[(X_valid, y_valid)])
# Out:
# [0]	validation_0-mlogloss:3.38355
# [1]	validation_0-mlogloss:3.24045
# [2]	validation_0-mlogloss:3.10802
# [3]	validation_0-mlogloss:3.00479
# [4]	validation_0-mlogloss:2.91282
# [5]	validation_0-mlogloss:2.81814
# [6]	validation_0-mlogloss:2.74687
# [7]	validation_0-mlogloss:2.67309
# [8]	validation_0-mlogloss:2.60718
# [9]	validation_0-mlogloss:2.55553
# [10]	validation_0-mlogloss:2.50529
# [11]	validation_0-mlogloss:2.45737
# [12]	validation_0-mlogloss:2.41289
# [13]	validation_0-mlogloss:2.37233
# [14]	validation_0-mlogloss:2.33291
# [15]	validation_0-mlogloss:2.29415
# [16]	validation_0-mlogloss:2.26067
# [17]	validation_0-mlogloss:2.22482
# [18]	validation_0-mlogloss:2.19397
# [19]	validation_0-mlogloss:2.16191
# [20]	validation_0-mlogloss:2.13087
# [21]	validation_0-mlogloss:2.09923
# [22]	validation_0-mlogloss:2.07275
# [23]	validation_0-mlogloss:2.05016
# [24]	validation_0-mlogloss:2.02872
# [25]	validation_0-mlogloss:2.00799
# [26]	validation_0-mlogloss:1.98412
# [27]	validation_0-mlogloss:1.95722
# [28]	validation_0-mlogloss:1.93570
# [29]	validation_0-mlogloss:1.91362
# [30]	validation_0-mlogloss:1.89172
# [31]	validation_0-mlogloss:1.87008
# [32]	validation_0-mlogloss:1.84880
# [33]	validation_0-mlogloss:1.83119
# [34]	validation_0-mlogloss:1.81087
# [35]	validation_0-mlogloss:1.79162
# [36]	validation_0-mlogloss:1.77087
# [37]	validation_0-mlogloss:1.75242
# [38]	validation_0-mlogloss:1.73703
# [39]	validation_0-mlogloss:1.72035
# [40]	validation_0-mlogloss:1.70389
# [41]	validation_0-mlogloss:1.68725
# [42]	validation_0-mlogloss:1.67152
# [43]	validation_0-mlogloss:1.65686
# [44]	validation_0-mlogloss:1.64177
# [45]	validation_0-mlogloss:1.62638
# [46]	validation_0-mlogloss:1.61380
# [47]	validation_0-mlogloss:1.60068
# [48]	validation_0-mlogloss:1.58754
# [49]	validation_0-mlogloss:1.57417
# [50]	validation_0-mlogloss:1.56188
# [51]	validation_0-mlogloss:1.54880
# [52]	validation_0-mlogloss:1.53546
# [53]	validation_0-mlogloss:1.52389
# [54]	validation_0-mlogloss:1.51030
# [55]	validation_0-mlogloss:1.49756
# [56]	validation_0-mlogloss:1.48698
# [57]	validation_0-mlogloss:1.47470
# [58]	validation_0-mlogloss:1.46494
# [59]	validation_0-mlogloss:1.45441
# [60]	validation_0-mlogloss:1.44517
# [61]	validation_0-mlogloss:1.43552
# [62]	validation_0-mlogloss:1.42618
# [63]	validation_0-mlogloss:1.41651
# [64]	validation_0-mlogloss:1.40765
# [65]	validation_0-mlogloss:1.39752
# [66]	validation_0-mlogloss:1.38938
# [67]	validation_0-mlogloss:1.38061
# [68]	validation_0-mlogloss:1.37225
# [69]	validation_0-mlogloss:1.36302
# [70]	validation_0-mlogloss:1.35397
# [71]	validation_0-mlogloss:1.34627
# [72]	validation_0-mlogloss:1.33798
# [73]	validation_0-mlogloss:1.33124
# [74]	validation_0-mlogloss:1.32320
# [75]	validation_0-mlogloss:1.31674
# [76]	validation_0-mlogloss:1.30891
# [77]	validation_0-mlogloss:1.30230
# [78]	validation_0-mlogloss:1.29586
# [79]	validation_0-mlogloss:1.28869
# [80]	validation_0-mlogloss:1.28190
# [81]	validation_0-mlogloss:1.27590
# [82]	validation_0-mlogloss:1.26781
# [83]	validation_0-mlogloss:1.26131
# [84]	validation_0-mlogloss:1.25513
# [85]	validation_0-mlogloss:1.24969
# [86]	validation_0-mlogloss:1.24277
# [87]	validation_0-mlogloss:1.23784
# [88]	validation_0-mlogloss:1.23239
# [89]	validation_0-mlogloss:1.22584
# [90]	validation_0-mlogloss:1.21963
# [91]	validation_0-mlogloss:1.21322
# [92]	validation_0-mlogloss:1.20796
# [93]	validation_0-mlogloss:1.20163
# [94]	validation_0-mlogloss:1.19585
# [95]	validation_0-mlogloss:1.19174
# [96]	validation_0-mlogloss:1.18669
# [97]	validation_0-mlogloss:1.18053
# [98]	validation_0-mlogloss:1.17584
# [99]	validation_0-mlogloss:1.17148
# [100]	validation_0-mlogloss:1.16759
# [101]	validation_0-mlogloss:1.16374
# [102]	validation_0-mlogloss:1.15796
# [103]	validation_0-mlogloss:1.15388
# [104]	validation_0-mlogloss:1.14872
# [105]	validation_0-mlogloss:1.14466
# [106]	validation_0-mlogloss:1.14085
# [107]	validation_0-mlogloss:1.13725
# [108]	validation_0-mlogloss:1.13287
# [109]	validation_0-mlogloss:1.12833
# [110]	validation_0-mlogloss:1.12376
# [111]	validation_0-mlogloss:1.11919
# [112]	validation_0-mlogloss:1.11396
# [113]	validation_0-mlogloss:1.10977
# [114]	validation_0-mlogloss:1.10631
# [115]	validation_0-mlogloss:1.10181
# [116]	validation_0-mlogloss:1.09863
# [117]	validation_0-mlogloss:1.09516
# [118]	validation_0-mlogloss:1.09172
# [119]	validation_0-mlogloss:1.08871
# [120]	validation_0-mlogloss:1.08568
# [121]	validation_0-mlogloss:1.08226
# [122]	validation_0-mlogloss:1.07903
# [123]	validation_0-mlogloss:1.07553
# [124]	validation_0-mlogloss:1.07244
# [125]	validation_0-mlogloss:1.06977
# [126]	validation_0-mlogloss:1.06671
# [127]	validation_0-mlogloss:1.06358
# [128]	validation_0-mlogloss:1.06098
# [129]	validation_0-mlogloss:1.05723
# [130]	validation_0-mlogloss:1.05374
# [131]	validation_0-mlogloss:1.05104
# [132]	validation_0-mlogloss:1.04840
# [133]	validation_0-mlogloss:1.04533
# [134]	validation_0-mlogloss:1.04303
# [135]	validation_0-mlogloss:1.04014
# [136]	validation_0-mlogloss:1.03842
# [137]	validation_0-mlogloss:1.03530
# [138]	validation_0-mlogloss:1.03281
# [139]	validation_0-mlogloss:1.03038
# [140]	validation_0-mlogloss:1.02796
# [141]	validation_0-mlogloss:1.02547
# [142]	validation_0-mlogloss:1.02234
# [143]	validation_0-mlogloss:1.02033
# [144]	validation_0-mlogloss:1.01836
# [145]	validation_0-mlogloss:1.01607
# [146]	validation_0-mlogloss:1.01373
# [147]	validation_0-mlogloss:1.01086
# [148]	validation_0-mlogloss:1.00856
# [149]	validation_0-mlogloss:1.00620
# [150]	validation_0-mlogloss:1.00338
# [151]	validation_0-mlogloss:1.00111
# [152]	validation_0-mlogloss:0.99931
# [153]	validation_0-mlogloss:0.99702
# [154]	validation_0-mlogloss:0.99531
# [155]	validation_0-mlogloss:0.99306
# [156]	validation_0-mlogloss:0.99135
# [157]	validation_0-mlogloss:0.98950
# [158]	validation_0-mlogloss:0.98752
# [159]	validation_0-mlogloss:0.98530
# [160]	validation_0-mlogloss:0.98371
# [161]	validation_0-mlogloss:0.98200
# [162]	validation_0-mlogloss:0.97945
# [163]	validation_0-mlogloss:0.97809
# [164]	validation_0-mlogloss:0.97672
# [165]	validation_0-mlogloss:0.97499
# [166]	validation_0-mlogloss:0.97352
# [167]	validation_0-mlogloss:0.97212
# [168]	validation_0-mlogloss:0.97045
# [169]	validation_0-mlogloss:0.96849
# [170]	validation_0-mlogloss:0.96705
# [171]	validation_0-mlogloss:0.96510
# [172]	validation_0-mlogloss:0.96386
# [173]	validation_0-mlogloss:0.96207
# [174]	validation_0-mlogloss:0.96021
# [175]	validation_0-mlogloss:0.95913
# [176]	validation_0-mlogloss:0.95766
# [177]	validation_0-mlogloss:0.95608
# [178]	validation_0-mlogloss:0.95432
# [179]	validation_0-mlogloss:0.95302
# [180]	validation_0-mlogloss:0.95165
# [181]	validation_0-mlogloss:0.94982
# [182]	validation_0-mlogloss:0.94825
# [183]	validation_0-mlogloss:0.94649
# [184]	validation_0-mlogloss:0.94555
# [185]	validation_0-mlogloss:0.94395
# [186]	validation_0-mlogloss:0.94336
# [187]	validation_0-mlogloss:0.94233
# [188]	validation_0-mlogloss:0.94043
# [189]	validation_0-mlogloss:0.93878
# [190]	validation_0-mlogloss:0.93672
# [191]	validation_0-mlogloss:0.93494
# [192]	validation_0-mlogloss:0.93325
# [193]	validation_0-mlogloss:0.93201
# [194]	validation_0-mlogloss:0.93071
# [195]	validation_0-mlogloss:0.92926
# [196]	validation_0-mlogloss:0.92760
# [197]	validation_0-mlogloss:0.92619
# [198]	validation_0-mlogloss:0.92493
# [199]	validation_0-mlogloss:0.92323
# [200]	validation_0-mlogloss:0.92220
# [201]	validation_0-mlogloss:0.92100
# [202]	validation_0-mlogloss:0.91973
# [203]	validation_0-mlogloss:0.91879
# [204]	validation_0-mlogloss:0.91773
# [205]	validation_0-mlogloss:0.91689
# [206]	validation_0-mlogloss:0.91647
# [207]	validation_0-mlogloss:0.91517
# [208]	validation_0-mlogloss:0.91400
# [209]	validation_0-mlogloss:0.91306
# [210]	validation_0-mlogloss:0.91212
# [211]	validation_0-mlogloss:0.91106
# [212]	validation_0-mlogloss:0.91024
# [213]	validation_0-mlogloss:0.90910
# [214]	validation_0-mlogloss:0.90813
# [215]	validation_0-mlogloss:0.90693
# [216]	validation_0-mlogloss:0.90599
# [217]	validation_0-mlogloss:0.90490
# [218]	validation_0-mlogloss:0.90434
# [219]	validation_0-mlogloss:0.90368
# [220]	validation_0-mlogloss:0.90225
# [221]	validation_0-mlogloss:0.90150
# [222]	validation_0-mlogloss:0.90054
# [223]	validation_0-mlogloss:0.89975
# [224]	validation_0-mlogloss:0.89845
# [225]	validation_0-mlogloss:0.89782
# [226]	validation_0-mlogloss:0.89735
# [227]	validation_0-mlogloss:0.89674
# [228]	validation_0-mlogloss:0.89608
# [229]	validation_0-mlogloss:0.89522
# [230]	validation_0-mlogloss:0.89436
# [231]	validation_0-mlogloss:0.89362
# [232]	validation_0-mlogloss:0.89286
# [233]	validation_0-mlogloss:0.89211
# [234]	validation_0-mlogloss:0.89119
# [235]	validation_0-mlogloss:0.89028
# [236]	validation_0-mlogloss:0.88999
# [237]	validation_0-mlogloss:0.88912
# [238]	validation_0-mlogloss:0.88853
# [239]	validation_0-mlogloss:0.88750
# [240]	validation_0-mlogloss:0.88701
# [241]	validation_0-mlogloss:0.88648
# [242]	validation_0-mlogloss:0.88573
# [243]	validation_0-mlogloss:0.88509
# [244]	validation_0-mlogloss:0.88432
# [245]	validation_0-mlogloss:0.88390
# [246]	validation_0-mlogloss:0.88388
# [247]	validation_0-mlogloss:0.88294
# [248]	validation_0-mlogloss:0.88225
# [249]	validation_0-mlogloss:0.88186
# [250]	validation_0-mlogloss:0.88100
# [251]	validation_0-mlogloss:0.88038
# [252]	validation_0-mlogloss:0.87971
# [253]	validation_0-mlogloss:0.87916
# [254]	validation_0-mlogloss:0.87854
# [255]	validation_0-mlogloss:0.87806
# [256]	validation_0-mlogloss:0.87753
# [257]	validation_0-mlogloss:0.87704
# [258]	validation_0-mlogloss:0.87664
# [259]	validation_0-mlogloss:0.87552
# [260]	validation_0-mlogloss:0.87493
# [261]	validation_0-mlogloss:0.87438
# [262]	validation_0-mlogloss:0.87387
# [263]	validation_0-mlogloss:0.87358
# [264]	validation_0-mlogloss:0.87312
# [265]	validation_0-mlogloss:0.87216
# [266]	validation_0-mlogloss:0.87153
# [267]	validation_0-mlogloss:0.87086
# [268]	validation_0-mlogloss:0.87046
# [269]	validation_0-mlogloss:0.86944
# [270]	validation_0-mlogloss:0.86890
# [271]	validation_0-mlogloss:0.86828
# [272]	validation_0-mlogloss:0.86768
# [273]	validation_0-mlogloss:0.86681
# [274]	validation_0-mlogloss:0.86615
# [275]	validation_0-mlogloss:0.86573
# [276]	validation_0-mlogloss:0.86536
# [277]	validation_0-mlogloss:0.86496
# [278]	validation_0-mlogloss:0.86451
# [279]	validation_0-mlogloss:0.86413
# [280]	validation_0-mlogloss:0.86370
# [281]	validation_0-mlogloss:0.86300
# [282]	validation_0-mlogloss:0.86267
# [283]	validation_0-mlogloss:0.86194
# [284]	validation_0-mlogloss:0.86160
# [285]	validation_0-mlogloss:0.86153
# [286]	validation_0-mlogloss:0.86099
# [287]	validation_0-mlogloss:0.86096
# [288]	validation_0-mlogloss:0.86055
# [289]	validation_0-mlogloss:0.86029
# [290]	validation_0-mlogloss:0.85992
# [291]	validation_0-mlogloss:0.85930
# [292]	validation_0-mlogloss:0.85874
# [293]	validation_0-mlogloss:0.85833
# [294]	validation_0-mlogloss:0.85792
# [295]	validation_0-mlogloss:0.85761
# [296]	validation_0-mlogloss:0.85696
# [297]	validation_0-mlogloss:0.85643
# [298]	validation_0-mlogloss:0.85610
# [299]	validation_0-mlogloss:0.85576
# [300]	validation_0-mlogloss:0.85525
# [301]	validation_0-mlogloss:0.85509
# [302]	validation_0-mlogloss:0.85481
# [303]	validation_0-mlogloss:0.85461
# [304]	validation_0-mlogloss:0.85414
# [305]	validation_0-mlogloss:0.85357
# [306]	validation_0-mlogloss:0.85299
# [307]	validation_0-mlogloss:0.85270
# [308]	validation_0-mlogloss:0.85223
# [309]	validation_0-mlogloss:0.85177
# [310]	validation_0-mlogloss:0.85127
# [311]	validation_0-mlogloss:0.85098
# [312]	validation_0-mlogloss:0.85040
# [313]	validation_0-mlogloss:0.85000
# [314]	validation_0-mlogloss:0.84955
# [315]	validation_0-mlogloss:0.84907
# [316]	validation_0-mlogloss:0.84859
# [317]	validation_0-mlogloss:0.84797
# [318]	validation_0-mlogloss:0.84767
# [319]	validation_0-mlogloss:0.84747
# [320]	validation_0-mlogloss:0.84705
# [321]	validation_0-mlogloss:0.84684
# [322]	validation_0-mlogloss:0.84662
# [323]	validation_0-mlogloss:0.84641
# [324]	validation_0-mlogloss:0.84623
# [325]	validation_0-mlogloss:0.84569
# [326]	validation_0-mlogloss:0.84533
# [327]	validation_0-mlogloss:0.84492
# [328]	validation_0-mlogloss:0.84454
# [329]	validation_0-mlogloss:0.84398
# [330]	validation_0-mlogloss:0.84352
# [331]	validation_0-mlogloss:0.84295
# [332]	validation_0-mlogloss:0.84256
# [333]	validation_0-mlogloss:0.84214
# [334]	validation_0-mlogloss:0.84191
# [335]	validation_0-mlogloss:0.84190
# [336]	validation_0-mlogloss:0.84155
# [337]	validation_0-mlogloss:0.84116
# [338]	validation_0-mlogloss:0.84096
# [339]	validation_0-mlogloss:0.84095
# [340]	validation_0-mlogloss:0.84071
# [341]	validation_0-mlogloss:0.84033
# [342]	validation_0-mlogloss:0.84023
# [343]	validation_0-mlogloss:0.83978
# [344]	validation_0-mlogloss:0.83953
# [345]	validation_0-mlogloss:0.83916
# [346]	validation_0-mlogloss:0.83888
# [347]	validation_0-mlogloss:0.83871
# [348]	validation_0-mlogloss:0.83873
# [349]	validation_0-mlogloss:0.83840
# [350]	validation_0-mlogloss:0.83806
# [351]	validation_0-mlogloss:0.83790
# [352]	validation_0-mlogloss:0.83778
# [353]	validation_0-mlogloss:0.83758
# [354]	validation_0-mlogloss:0.83763
# [355]	validation_0-mlogloss:0.83746
# [356]	validation_0-mlogloss:0.83712
# [357]	validation_0-mlogloss:0.83681
# [358]	validation_0-mlogloss:0.83664
# [359]	validation_0-mlogloss:0.83647
# [360]	validation_0-mlogloss:0.83639
# [361]	validation_0-mlogloss:0.83620
# [362]	validation_0-mlogloss:0.83602
# [363]	validation_0-mlogloss:0.83579
# [364]	validation_0-mlogloss:0.83593
# [365]	validation_0-mlogloss:0.83571
# [366]	validation_0-mlogloss:0.83558
# [367]	validation_0-mlogloss:0.83540
# [368]	validation_0-mlogloss:0.83508
# [369]	validation_0-mlogloss:0.83497
# [370]	validation_0-mlogloss:0.83467
# [371]	validation_0-mlogloss:0.83455
# [372]	validation_0-mlogloss:0.83421
# [373]	validation_0-mlogloss:0.83395
# [374]	validation_0-mlogloss:0.83387
# [375]	validation_0-mlogloss:0.83370
# [376]	validation_0-mlogloss:0.83345
# [377]	validation_0-mlogloss:0.83316
# [378]	validation_0-mlogloss:0.83286
# [379]	validation_0-mlogloss:0.83262
# [380]	validation_0-mlogloss:0.83228
# [381]	validation_0-mlogloss:0.83211
# [382]	validation_0-mlogloss:0.83164
# [383]	validation_0-mlogloss:0.83149
# [384]	validation_0-mlogloss:0.83161
# [385]	validation_0-mlogloss:0.83142
# [386]	validation_0-mlogloss:0.83143
# [387]	validation_0-mlogloss:0.83135
# [388]	validation_0-mlogloss:0.83131
# [389]	validation_0-mlogloss:0.83099
# [390]	validation_0-mlogloss:0.83104
# [391]	validation_0-mlogloss:0.83062
# [392]	validation_0-mlogloss:0.83029
# [393]	validation_0-mlogloss:0.82977
# [394]	validation_0-mlogloss:0.82949
# [395]	validation_0-mlogloss:0.82926
# [396]	validation_0-mlogloss:0.82889
# [397]	validation_0-mlogloss:0.82860
# [398]	validation_0-mlogloss:0.82824
# [399]	validation_0-mlogloss:0.82792
# [400]	validation_0-mlogloss:0.82778
# [401]	validation_0-mlogloss:0.82754
# [402]	validation_0-mlogloss:0.82727
# [403]	validation_0-mlogloss:0.82701
# [404]	validation_0-mlogloss:0.82685
# [405]	validation_0-mlogloss:0.82668
# [406]	validation_0-mlogloss:0.82671
# [407]	validation_0-mlogloss:0.82655
# [408]	validation_0-mlogloss:0.82639
# [409]	validation_0-mlogloss:0.82630
# [410]	validation_0-mlogloss:0.82629
# [411]	validation_0-mlogloss:0.82586
# [412]	validation_0-mlogloss:0.82563
# [413]	validation_0-mlogloss:0.82542
# [414]	validation_0-mlogloss:0.82527
# [415]	validation_0-mlogloss:0.82503
# [416]	validation_0-mlogloss:0.82494
# [417]	validation_0-mlogloss:0.82465
# [418]	validation_0-mlogloss:0.82460
# [419]	validation_0-mlogloss:0.82462
# [420]	validation_0-mlogloss:0.82441
# [421]	validation_0-mlogloss:0.82416
# [422]	validation_0-mlogloss:0.82396
# [423]	validation_0-mlogloss:0.82380
# [424]	validation_0-mlogloss:0.82375
# [425]	validation_0-mlogloss:0.82366
# [426]	validation_0-mlogloss:0.82340
# [427]	validation_0-mlogloss:0.82301
# [428]	validation_0-mlogloss:0.82291
# [429]	validation_0-mlogloss:0.82282
# [430]	validation_0-mlogloss:0.82269
# [431]	validation_0-mlogloss:0.82255
# [432]	validation_0-mlogloss:0.82237
# [433]	validation_0-mlogloss:0.82219
# [434]	validation_0-mlogloss:0.82195
# [435]	validation_0-mlogloss:0.82172
# [436]	validation_0-mlogloss:0.82162
# [437]	validation_0-mlogloss:0.82145
# [438]	validation_0-mlogloss:0.82143
# [439]	validation_0-mlogloss:0.82106
# [440]	validation_0-mlogloss:0.82109
# [441]	validation_0-mlogloss:0.82086
# [442]	validation_0-mlogloss:0.82076
# [443]	validation_0-mlogloss:0.82076
# [444]	validation_0-mlogloss:0.82059
# [445]	validation_0-mlogloss:0.82043
# [446]	validation_0-mlogloss:0.82038
# [447]	validation_0-mlogloss:0.82031
# [448]	validation_0-mlogloss:0.82006
# [449]	validation_0-mlogloss:0.81986
# [450]	validation_0-mlogloss:0.81967
# [451]	validation_0-mlogloss:0.81928
# [452]	validation_0-mlogloss:0.81902
# [453]	validation_0-mlogloss:0.81902
# [454]	validation_0-mlogloss:0.81891
# [455]	validation_0-mlogloss:0.81869
# [456]	validation_0-mlogloss:0.81868
# [457]	validation_0-mlogloss:0.81863
# [458]	validation_0-mlogloss:0.81848
# [459]	validation_0-mlogloss:0.81830
# [460]	validation_0-mlogloss:0.81806
# [461]	validation_0-mlogloss:0.81809
# [462]	validation_0-mlogloss:0.81785
# [463]	validation_0-mlogloss:0.81757
# [464]	validation_0-mlogloss:0.81740
# [465]	validation_0-mlogloss:0.81738
# [466]	validation_0-mlogloss:0.81735
# [467]	validation_0-mlogloss:0.81718
# [468]	validation_0-mlogloss:0.81695
# [469]	validation_0-mlogloss:0.81669
# [470]	validation_0-mlogloss:0.81640
# [471]	validation_0-mlogloss:0.81638
# [472]	validation_0-mlogloss:0.81625
# [473]	validation_0-mlogloss:0.81600
# [474]	validation_0-mlogloss:0.81592
# [475]	validation_0-mlogloss:0.81589
# [476]	validation_0-mlogloss:0.81562
# [477]	validation_0-mlogloss:0.81552
# [478]	validation_0-mlogloss:0.81541
# [479]	validation_0-mlogloss:0.81507
# [480]	validation_0-mlogloss:0.81482
# [481]	validation_0-mlogloss:0.81468
# [482]	validation_0-mlogloss:0.81476
# [483]	validation_0-mlogloss:0.81450
# [484]	validation_0-mlogloss:0.81444
# [485]	validation_0-mlogloss:0.81422
# [486]	validation_0-mlogloss:0.81414
# [487]	validation_0-mlogloss:0.81406
# [488]	validation_0-mlogloss:0.81382
# [489]	validation_0-mlogloss:0.81372
# [490]	validation_0-mlogloss:0.81353
# [491]	validation_0-mlogloss:0.81342
# [492]	validation_0-mlogloss:0.81333
# [493]	validation_0-mlogloss:0.81308
# [494]	validation_0-mlogloss:0.81314
# [495]	validation_0-mlogloss:0.81327
# [496]	validation_0-mlogloss:0.81314
# [497]	validation_0-mlogloss:0.81296
# [498]	validation_0-mlogloss:0.81284
# [499]	validation_0-mlogloss:0.81270
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[506], line 20
#      17 svm = SVC(kernel='cosine', probability=True, class_weight="balanced")
#      19 clf.fit(X_train, y_train, eval_set=[(X_valid, y_valid)])
# ---> 20 svm.fit(X_train, y_train)
#
# File ~/miniconda3/envs/DataMind/lib/python3.10/site-packages/sklearn/base.py:1356, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1351 partial_fit_and_fitted = (
#    1352     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1353 )
#    1355 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
#    1363     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/DataMind/lib/python3.10/site-packages/sklearn/base.py:469, in BaseEstimator._validate_params(self)
#     461 def _validate_params(self):
#     462     """Validate types and values of constructor parameters
#     463
#     464     The expected type and values must be defined in the `_parameter_constraints`
#    (...)
#     467     accepted constraints.
#     468     """
# --> 469     validate_parameter_constraints(
#     470         self._parameter_constraints,
#     471         self.get_params(deep=False),
#     472         caller_name=self.__class__.__name__,
#     473     )
#
# File ~/miniconda3/envs/DataMind/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:98, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      92 else:
#      93     constraints_str = (
#      94         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      95         f" {constraints[-1]}"
#      96     )
# ---> 98 raise InvalidParameterError(
#      99     f"The {param_name!r} parameter of {caller_name} must be"
#     100     f" {constraints_str}. Got {param_val!r} instead."
#     101 )
#
# InvalidParameterError: The 'kernel' parameter of SVC must be a str among {'precomputed', 'linear', 'sigmoid', 'poly', 'rbf'} or a callable. Got 'cosine' instead.

# %%
svm = SVC(kernel='linear', probability=True, class_weight="balanced")
svm.fit(X_train, y_train)
# Out:
# SVC(class_weight='balanced', kernel='linear', probability=True)

# %%
from sklearn.metrics import accuracy_score

def macro_accuracy(y_true, y_pred):
    classes = np.unique(y_true)
    acc_per_class = []
    for c in classes:
        mask = y_true == c
        acc = accuracy_score(y_true[mask], y_pred[mask])
        acc_per_class.append(acc)
    return np.mean(acc_per_class)

# %%
from sklearn.metrics import balanced_accuracy_score, classification_report

def evaluate(model, X, y, name="", threshold=0.1):
    # Get prediction probabilities
    y_probs = model.predict_proba(X)
    
    # Apply threshold to create predictions
    confident_mask = np.max(y_probs, axis=1) >= threshold
    y_pred = np.where(confident_mask,
                     model.classes_[np.argmax(y_probs, axis=1)],
                     le.transform(['UNKNOWN'])[0])  # Map low-confidence to 'unknown'
    
    # Get only classes present in y_true or confident predictions
    present_labels = np.unique(np.concatenate([
        y,
        y_pred[confident_mask]  # Only consider confident predictions for class list
    ]))
    present_classes = le.classes_[present_labels]
    
    print(f"\n{name} Classification Report (Threshold={threshold}):")
    print(classification_report(
        y, y_pred,
        labels=present_labels,
        target_names=present_classes,
        zero_division=0,
        digits=4
    ))
    
    # Calculate macro accuracy considering unknowns as a separate class
    print(f"Macro Accuracy: {macro_accuracy(y, y_pred):.4f}")
    print(f"Unknown Ratio: {1 - confident_mask.mean():.2%}")

# %%
evaluate(clf, X_valid, y_valid, "XGBoost")
# Out:
# XGBoost Classification Report (Threshold=0.1):
#               precision    recall  f1-score   support
#
#      UNKNOWN     0.7222    0.6500    0.6842        20
#       emp001     0.6000    1.0000    0.7500         9
#       emp002     0.9375    0.9375    0.9375        16
#       emp003     0.8000    1.0000    0.8889         4
#       emp004     0.8000    0.8889    0.8421         9
#       emp006     1.0000    1.0000    1.0000         5
#       emp007     1.0000    1.0000    1.0000         1
#       emp008     0.0000    0.0000    0.0000         0
#       emp009     1.0000    0.3333    0.5000         3
#       emp010     0.9375    0.8824    0.9091        17
#       emp011     1.0000    1.0000    1.0000         9
#       emp012     1.0000    0.8333    0.9091         6
#       emp013     0.4000    0.4000    0.4000         5
#       emp014     0.9375    0.9375    0.9375        16
#       emp015     0.6667    0.6667    0.6667         3
#       emp016     0.9474    0.9474    0.9474        19
#       emp017     0.0000    0.0000    0.0000         1
#       emp018     0.8889    0.8889    0.8889         9
#       emp019     0.6667    0.7143    0.6897        14
#       emp020     0.8696    0.9524    0.9091        21
#       emp021     0.8750    0.7000    0.7778        10
#       emp022     0.8333    0.5556    0.6667         9
#       emp023     1.0000    0.7500    0.8571         4
#       emp025     0.8000    1.0000    0.8889         4
#       emp026     0.0000    0.0000    0.0000         0
#       emp027     0.5000    1.0000    0.6667         1
#       emp028     1.0000    0.3333    0.5000         3
#       emp030     1.0000    0.6667    0.8000         3
#       emp031     0.6000    0.7500    0.6667         4
#       emp032     0.6667    1.0000    0.8000         2
#       emp034     1.0000    1.0000    1.0000         2
#       emp035     1.0000    0.8571    0.9231         7
#
#     accuracy                         0.8305       236
#    macro avg     0.7640    0.7389    0.7315       236
# weighted avg     0.8494    0.8305    0.8296       236
#
# Macro Accuracy: 0.7882
# Unknown Ratio: 1.69%

# %%
evaluate(svm, X_valid, y_valid, "SVM")
# Out:
# SVM Classification Report (Threshold=0.1):
#               precision    recall  f1-score   support
#
#      UNKNOWN     1.0000    0.8000    0.8889        20
#       emp001     0.6154    0.8889    0.7273         9
#       emp002     0.7895    0.9375    0.8571        16
#       emp003     1.0000    1.0000    1.0000         4
#       emp004     1.0000    0.8889    0.9412         9
#       emp006     1.0000    1.0000    1.0000         5
#       emp007     1.0000    1.0000    1.0000         1
#       emp009     0.6667    0.6667    0.6667         3
#       emp010     0.9412    0.9412    0.9412        17
#       emp011     1.0000    1.0000    1.0000         9
#       emp012     0.8333    0.8333    0.8333         6
#       emp013     1.0000    0.4000    0.5714         5
#       emp014     0.9412    1.0000    0.9697        16
#       emp015     0.6667    0.6667    0.6667         3
#       emp016     0.9474    0.9474    0.9474        19
#       emp017     1.0000    1.0000    1.0000         1
#       emp018     0.6667    0.8889    0.7619         9
#       emp019     0.6875    0.7857    0.7333        14
#       emp020     0.8636    0.9048    0.8837        21
#       emp021     0.9000    0.9000    0.9000        10
#       emp022     0.8333    0.5556    0.6667         9
#       emp023     1.0000    0.7500    0.8571         4
#       emp025     1.0000    0.7500    0.8571         4
#       emp027     1.0000    1.0000    1.0000         1
#       emp028     1.0000    0.6667    0.8000         3
#       emp030     1.0000    0.6667    0.8000         3
#       emp031     0.6667    1.0000    0.8000         4
#       emp032     1.0000    1.0000    1.0000         2
#       emp034     1.0000    1.0000    1.0000         2
#       emp035     1.0000    0.8571    0.9231         7
#
#     accuracy                         0.8686       236
#    macro avg     0.9006    0.8565    0.8665       236
# weighted avg     0.8863    0.8686    0.8681       236
#
# Macro Accuracy: 0.8565
# Unknown Ratio: 0.00%

# %%
test_embed, test_filenames, missing_test = [], [], []
test_img_path = os.path.join(test_dir, "images")

for filename in tqdm(sorted(os.listdir(test_img_path)), desc="Creating Test Embeddings"):
    img_path = os.path.join(test_img_path, filename)
    img = cv2.imread(img_path)
    faces = robust_face_detection(img, app)
    test_filenames.append(img_path)
    if faces:
        test_embed.append(faces[0].embedding)
    else:
        test_embed.append(np.random.normal(0, 0.01, 512))
        missing_test.append(img_path)
# Out:
# Creating Test Embeddings:   0%|          | 0/636 [00:00<?, ?it/s]/home/seang/miniconda3/envs/DataMind/lib/python3.10/site-packages/insightface/utils/transform.py:68: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   P = np.linalg.lstsq(X_homo, Y)[0].T # Affine matrix. 3 x 4
# Creating Test Embeddings: 100%|██████████| 636/636 [02:51<00:00,  3.70it/s]

# %%
def thresholded_predict(model, X, classes, threshold=0.1, unknown_label='UNKNOWN'):
    """
    Make predictions using a confidence threshold
    
    Args:
        model: Trained classifier with predict_proba() method
        X: Input features (embeddings)
        classes: Array of class names (e.g., ['emp001', 'emp002', ...])
        threshold: Confidence threshold (0-1)
        unknown_label: Label for low-confidence predictions
    """
    # Get class probabilities
    try:
        probs = model.predict_proba(X)
    except AttributeError:
        raise ValueError("Model must have predict_proba() method")
    
    # Get max probability and corresponding class index
    max_probs = np.max(probs, axis=1)
    pred_indices = np.argmax(probs, axis=1)
    
    # Apply threshold
    predictions = np.where(max_probs >= threshold,
                         classes[pred_indices],
                         unknown_label)
    
    return predictions

test_data = np.array(test_embed)
svm_test_labels = thresholded_predict(svm, test_data, le.classes_)
xgb_test_labels = thresholded_predict(clf, test_data, le.classes_)

# %%
svm_test_labels[:10], xgb_test_labels[:10]
# Out:
# (array(['emp019', 'emp014', 'emp016', 'emp016', 'emp002', 'emp019',
#         'emp014', 'emp001', 'emp001', 'emp004'], dtype='<U7'),
#  array(['emp019', 'emp014', 'emp016', 'emp016', 'emp002', 'emp019',
#         'emp019', 'emp010', 'emp001', 'emp004'], dtype='<U7'))

# %%
submission = pd.DataFrame()
submission['filename'] = sorted(os.listdir(os.path.join(test_dir, "images")))
submission['employee_id'] = xgb_test_labels
submission['employee_id'] = submission['employee_id'].str.lower()

submission.head()
# Out:
#         filename employee_id
# 0  face_0002.jpg      emp019
# 1  face_0005.jpg      emp014
# 2  face_0009.jpg      emp016
# 3  face_0012.jpg      emp016
# 4  face_0014.jpg      emp002

# %%
submission.tail()
# Out:
#           filename employee_id
# 631  face_1802.jpg      emp023
# 632  face_1807.jpg      emp010
# 633  face_1812.jpg      emp020
# 634  face_1813.jpg      emp019
# 635  face_1815.jpg      emp009

# %%
def plot_test_predictions(submission, n=5):
    plt.figure(figsize=(15, 3))
    for i in range(n):
        idx = np.random.randint(len(submission))
        img = cv2.cvtColor(cv2.imread(test_filenames[idx]), cv2.COLOR_BGR2RGB)
        plt.subplot(1, n, i+1)
        plt.imshow(img)
        plt.title(f"{test_filenames[idx].split('/')[-1]} | Pred: {submission.iloc[idx]['employee_id']}")
        plt.axis('off')
    plt.tight_layout()

plot_test_predictions(submission)

# %%
submission.to_csv('submission.csv', index=False)
